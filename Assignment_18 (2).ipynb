# %%
# ================================
# ANN CLASSIFICATION - ALPHABETS
# ================================

# Import Libraries
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, accuracy_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# ================================
# LOAD DATA
# ================================
data = pd.read_csv("Alphabets_data.csv")

print("Dataset Shape:", data.shape)
print(data.head())

# ================================
# PREPROCESSING
# ================================

# Separate features and target
X = data.drop("letter", axis=1)   # assuming target column is 'letter'
y = data["letter"]

# Encode target labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# One-hot encoding
y_categorical = to_categorical(y_encoded)

# Feature Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_categorical, test_size=0.2, random_state=42
)

# ================================
# MODEL BUILDING (BASE MODEL)
# ================================
model = Sequential()

model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(y_categorical.shape[1], activation='softmax'))

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ================================
# TRAIN MODEL
# ================================
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.2
)



# ================================
# HYPERPARAMETER TUNING (IMPROVED MODEL)
# ================================
model_tuned = Sequential()

model_tuned.add(Dense(128, activation='relu', input_dim=X_train.shape[1]))
model_tuned.add(Dense(64, activation='relu'))
model_tuned.add(Dense(32, activation='relu'))
model_tuned.add(Dense(y_categorical.shape[1], activation='softmax'))

model_tuned.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_tuned = model_tuned.fit(
    X_train, y_train,
    epochs=30,
    batch_size=16,
    validation_split=0.2
)

# Evaluation of tuned model
y_pred_tuned = model_tuned.predict(X_test)
y_pred_tuned_classes = np.argmax(y_pred_tuned, axis=1)

print("\nTuned Model Accuracy:", accuracy_score(y_true, y_pred_tuned_classes))
print("\nTuned Model Report:\n", classification_report(y_true, y_pred_tuned_classes))

# %%
# ================================
# ANN CLASSIFICATION - ALPHABETS
# ================================

# Import Libraries
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, accuracy_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# %%
# ================================
# LOAD DATA
# ================================
data = pd.read_csv("Alphabets_data.csv")

print("Dataset Shape:", data.shape)
print(data.head())
# Out:
# Dataset Shape: (20000, 17)
#   letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  xybar  \
# 0      T     2     8      3       5      1     8    13      0      6      6
# 1      I     5    12      3       7      2    10     5      5      4     13
# 2      D     4    11      6       8      6    10     6      2      6     10
# 3      N     7    11      6       6      3     5     9      4      6      4
# 4      G     2     1      3       1      1     8     6      6      6      6
#
#    x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 0      10       8      0       8      0       8
# 1       3       9      2       8      4      10
# 2       3       7      3       7      3       9
# 3       4      10      6      10      2       8
# 4       5       9      1       7      5      10

# %%
# ================================
# PREPROCESSING
# ================================

# Separate features and target
X = data.drop("letter", axis=1)   # assuming target column is 'letter'
y = data["letter"]

# Encode target labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# One-hot encoding
y_categorical = to_categorical(y_encoded)

# Feature Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_categorical, test_size=0.2, random_state=42
)

# %%
# ================================
# MODEL BUILDING (BASE MODEL)
# ================================
model = Sequential()

model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(y_categorical.shape[1], activation='softmax'))

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# ================================
# TRAIN MODEL
# ================================
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4405 - loss: 2.0998 - val_accuracy: 0.6691 - val_loss: 1.2255
# Epoch 2/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7210 - loss: 0.9897 - val_accuracy: 0.7431 - val_loss: 0.8750
# Epoch 3/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7798 - loss: 0.7661 - val_accuracy: 0.7878 - val_loss: 0.7314
# Epoch 4/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8105 - loss: 0.6506 - val_accuracy: 0.8109 - val_loss: 0.6323
# Epoch 5/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8330 - loss: 0.5723 - val_accuracy: 0.8366 - val_loss: 0.5683
# Epoch 6/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8517 - loss: 0.5137 - val_accuracy: 0.8500 - val_loss: 0.5150
# Epoch 7/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8605 - loss: 0.4696 - val_accuracy: 0.8622 - val_loss: 0.4827
# Epoch 8/20
# ...

# %%
# ================================
# TRAIN MODEL
# ================================
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9314 - loss: 0.2198 - val_accuracy: 0.9094 - val_loss: 0.2810
# Epoch 2/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9320 - loss: 0.2143 - val_accuracy: 0.9156 - val_loss: 0.2683
# Epoch 3/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9344 - loss: 0.2051 - val_accuracy: 0.9147 - val_loss: 0.2713
# Epoch 4/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9370 - loss: 0.1992 - val_accuracy: 0.9162 - val_loss: 0.2615
# Epoch 5/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9388 - loss: 0.1925 - val_accuracy: 0.9194 - val_loss: 0.2502
# Epoch 6/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9416 - loss: 0.1856 - val_accuracy: 0.9212 - val_loss: 0.2525
# Epoch 7/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9448 - loss: 0.1797 - val_accuracy: 0.9169 - val_loss: 0.2555
# Epoch 8/20
# ...

# %%
# ================================
# HYPERPARAMETER TUNING (IMPROVED MODEL)
# ================================
model_tuned = Sequential()

model_tuned.add(Dense(128, activation='relu', input_dim=X_train.shape[1]))
model_tuned.add(Dense(64, activation='relu'))
model_tuned.add(Dense(32, activation='relu'))
model_tuned.add(Dense(y_categorical.shape[1], activation='softmax'))

model_tuned.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_tuned = model_tuned.fit(
    X_train, y_train,
    epochs=30,
    batch_size=16,
    validation_split=0.2
)

# Evaluation of tuned model
y_pred_tuned = model_tuned.predict(X_test)
y_pred_tuned_classes = np.argmax(y_pred_tuned, axis=1)

# Convert one-hot encoded y_test back to original labels for evaluation
y_test_labels = np.argmax(y_test, axis=1)

print("\nTuned Model Accuracy:", accuracy_score(y_test_labels, y_pred_tuned_classes))
print("\nTuned Model Report:\n", classification_report(y_test_labels, y_pred_tuned_classes))
# Out:
# Epoch 1/30
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5989 - loss: 1.3674 - val_accuracy: 0.7606 - val_loss: 0.8049
# Epoch 2/30
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8057 - loss: 0.6392 - val_accuracy: 0.8369 - val_loss: 0.5512
# Epoch 3/30
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8574 - loss: 0.4712 - val_accuracy: 0.8566 - val_loss: 0.4630
# Epoch 4/30
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8862 - loss: 0.3764 - val_accuracy: 0.8931 - val_loss: 0.3638
# Epoch 5/30
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9023 - loss: 0.3107 - val_accuracy: 0.9050 - val_loss: 0.3187
# ...
